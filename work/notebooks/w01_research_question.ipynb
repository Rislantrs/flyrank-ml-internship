# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Rislantrs/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# ==============================================================================
# 1. My Lane and Why
# ==============================================================================
# I choose Lane 2: Refresh / Content Opportunity Scoring.
# Based on the initial inspection of the starter dataset, it is observed that
# 54.21% of the total 30,000 content assets are experiencing a downward trend
# in visibility. Furthermore, there are nearly 10,000 pages classified as stale
# but still maintaining high exposure. Given the massive volume of pages to
# manage, tracking decaying pages manually is highly inefficient. This lane is
# well worth exploring over the next 7 weeks because it directly addresses the
# tactical need to preserve high-value organic traffic before it erodes completely.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# ==============================================================================
# 2. The Question: Decision, Action, Cost of a Wrong Call
# ==============================================================================
# * Research Question: How can we rank and prioritize the review queue for web
#   pages that exhibit declining performance trends yet still hold significant
#   search demand (impressions)?
# * Unit of Analysis: A single unique row per content identity (content_id).
# * Improved Decision: Weekly allocation of the editorial team's bandwidth
#   for content optimization and rewriting.
# * Concrete Action: Editors immediately take top-ranked candidates from the
#   system to update stale information, deepen topical depth, or fix page structure.
# * Cost of a Wrong Recommendation: A false positive (recommending a healthy page
#   for a rewrite) wastes roughly 3–5 hours of manual writing time per article.
#   A false negative (missing a decaying page) results in permanent loss of ad
#   revenue or conversions as competitors overtake the search rankings.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
raw_url = 'https://raw.githubusercontent.com/Rislantrs/flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv'

try:
    df = pd.read_csv(raw_url)
    print("Berhasil memuat dataset langsung dari GitHub!\n")

    # Hitung metrik riil pendukung
    total_pages = df['content_id'].nunique()
    declining_pages = df[df['trend_direction'] == 'down'].shape[0]
    pct_declining = (declining_pages / len(df)) * 100
    stale_high_intent = df[(df['content_age_days'] >= 180) & (df['impressions_90d'] >= 500)].shape[0]

    # Tampilkan hasil angka nyata
    print(f"Angka A (Total Halaman Unik): {total_pages}")
    print(f"Angka B (Persentase Tren Turun): {pct_declining:.2f}%")
    print(f"Angka C (Halaman Usang & Impresi Tinggi): {stale_high_intent}")

except Exception as e:
    print("Gagal memuat data. Periksa apakah repositori bersifat privat atau nama branch-nya bukan 'main'.")
    print(f"Error: {e}")
# Out:
# Berhasil memuat dataset langsung dari GitHub!
#
# Angka A (Total Halaman Unik): 30000
# Angka B (Persentase Tren Turun): 54.21%
# Angka C (Halaman Usang & Impresi Tinggi): 9929

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# ==============================================================================
# 4. Careful Words: What I Can and Can't Claim
# ==============================================================================
# This work is strictly designed as an operational decision-support system.
# * What I can claim: The model can measure, observe, and rank the directional
#   propensity of a page's decline based on historical, multi-dimensional search
#   signals.
# * What I cannot claim: This project does not provide causal proof that executing
#   a content refresh guarantees traffic recovery. Furthermore, it does not aim
#   to reverse-engineer or predict Google's core algorithm updates, as external
#   macro shocks and seasonality fall outside the observable measurements of this dataset.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
